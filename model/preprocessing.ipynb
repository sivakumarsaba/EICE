# %%
import os
import pandas as pd
#from utilities import process_columns,columnNames as clm
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'fin.csv', 'preprocessing.ipynb']

# %%
df=pd.read_csv('fin.csv',encoding='latin1')

# %%
df.head()
# Out:
#                                              Summary     Assignment group
# 0                   Request to provide access in RSA        INFRA_NETWORK
# 1                            Hardware Update Request  INFRA_EUC_ASSETMGMT
# 2  Workflow DB - User Access Request - Colleen Ta...            INFRA_DBA
# 3  Grant access to Talend service account svc_dat...         INFRA_WINTEL
# 4         Search documents & Outlook for Mark Denyer      INFRA_MESSAGING

# %%
#getting numbers of rows and columns
nr,nc=df.shape
nr,nc
# Out:
# (104895, 2)

# %%
check_if_str=lambda entry: type(entry)== str

# %%
df=df.drop_duplicates(subset='Summary',keep='first')

# %%
df.head()
# Out:
#                                              Summary     Assignment group
# 0                   Request to provide access in RSA        INFRA_NETWORK
# 1                            Hardware Update Request  INFRA_EUC_ASSETMGMT
# 2  Workflow DB - User Access Request - Colleen Ta...            INFRA_DBA
# 3  Grant access to Talend service account svc_dat...         INFRA_WINTEL
# 4         Search documents & Outlook for Mark Denyer      INFRA_MESSAGING

# %%
df.shape
# Out:
# (101870, 2)

# %%
df.to_csv('processed_inciden_18months.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-19ba3bcd9322> in <module>
# ----> 1 df.to_csv('processed_inciden_18months.csv',index=False)
#
# NameError: name 'df' is not defined
